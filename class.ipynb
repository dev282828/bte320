# %% [markdown]
# <a href="https://colab.research.google.com/github/dev282828/bte320/blob/main/class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
interest = 0.03
principal = 3000
n = 1

final = principal * (1 + interest) ** n
print(final)
# Out:
# 3090.0

# %%
print(interest, principal)
print(n)
# Out:
# 0.03 3000
# 1

# %%
print("Interes rate", interest, sep="=>")
print("number of years:", n)
# Out:
# Interes rate=>0.03
# number of years: 1

# %%
print("interest rate:", interest, end="---")
print("number of years:", n, sep="")
# Out:
# interest rate: 0.03---number of years:1

# %%
print("Interes rate", interest, sep=">>>", end="&&&")
print("number of years:", n)
# Out:
# Interes rate>>>0.03&&&number of years: 1

# %%
print("Interest rate;", interest, "; number of years = ", n)
# Out:
# Interest rate; 0.03 ; number of years =  1

# %%
print("interest rate: {}; number of year {}".format(interest,n))
# Out:
# interest rate: 0.03; number of year 1

# %%
print(f"interest rate: {interest}; number of years = {n}")
# Out:
# interest rate: 0.03; number of years = 1

# %%
# Out:
# 0.03

# %%
interest = float(input("Give the interest value (%): "))
principal = float(input("Provide initial amount ($)"))
n = int(input("Enter number of years: "))
final = principal * (1+interest/100)**n
print(f"Total amount after {n} years(s): {final}$")
# Out:
# Give the interest value (%): 3
# Provide initial amount ($)3000
# Enter number of years: 1
# Total amount after 1 years(s): 3090.0$
